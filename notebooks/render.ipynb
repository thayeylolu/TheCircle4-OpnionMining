# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv('../data/processed/sentiments.csv')
player_info = pd.read_excel('../data/raw/players_info.xlsx')
df.head()
# Out:
#    Unnamed: 0 sentiments             user  \
# 0           0   POSITIVE    beardsational
# 1           1   POSITIVE     KingDelfrano
# 2           2   POSITIVE          KMJeezy
# 3           3   NEGATIVE  Blake_Jorgensen
# 4           4   NEGATIVE         jceron12
#
#                                                tweet  \
# 0  I’m sorry, but if you received two party invit...
# 1  enjoying this season of #TheCircle so far… nob...
# 2  Ok I aint like Yu Ling at first but she is com...
# 3  I need someone to watch #TheCircle with me so ...
# 4  I haven’t been seeing any tweets about #thecir...
#
#                                              hashtag           player
# 0                  ['TheCircle', 'TheCircleNetflix']            set()
# 1                                      ['TheCircle']  {'playereight'}
# 2                                      ['TheCircle']    {'playertwo'}
# 3                                      ['TheCircle']     {'playeron'}
# ...

# %%
df_player = df[df.player !='set()']

# %%
player_set = {'playerone', 'playertwo', 'playertheee', 'playerfour', 'playerfive',
              'playersix', 'playerseven', 'playereight', 'playernine',
              'playerten', 'playereleven', 'playertwelve'}

            
player_dict = dict(zip(list(player_info.full_name), list(player_info.playerno)))
player_list = list(player_info.full_name)

# %%
player_info[['full_name', 'playerno']]
# Out:
#          full_name     playerno
# 0            Frank     playeron
# 1       Yu Ling Wu    playertwo
# 2   Crissa Jackson    playerthr
# 3            Carol   playerfour
# 4           Alyssa      playerf
# 5              Bru    playersix
# 6             Paul  playerseven
# 7            Jared  playereight
# 8            Jared  playereight
# 9          Rachael    playernin
# 10          Nathan    playerten
# 11         Everson  playerelven
# 12          Imaani  playertwelv

# %%
df_player
# Out:
#        Unnamed: 0 sentiments             user  \
# 1               1   POSITIVE     KingDelfrano
# 2               2   POSITIVE          KMJeezy
# 3               3   NEGATIVE  Blake_Jorgensen
# 8               8   POSITIVE  borninthe1900s_
# 9               9   NEGATIVE       HealthyRis
# ...           ...        ...              ...
# 21991       21991   POSITIVE      brkichbuffs
# 21992       21992   NEGATIVE          SuziGTV
# 21993       21993   POSITIVE      brkichbuffs
# 22001       22001   NEGATIVE        ChantieMG
# 22004       22004   POSITIVE  adrianneromcel2
#
#                                                    tweet  \
# 1      enjoying this season of #TheCircle so far… nob...
# 2      Ok I aint like Yu Ling at first but she is com...
# 3      I need someone to watch #TheCircle with me so ...
# 8      Bru shouldn't make my ovaries hurt but he does...
# 9      I’m so annoyed with this season. Why did the S...
# ...                                                  ...
# ...
